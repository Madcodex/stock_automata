# %%
import pandas as pd

# %%
df = pd.read_html("https://www.moneyworks4me.com/best-index/nse-stocks/top-nse100-companies-list/")

# %%
df[0]
# Out:
#     Unnamed: 0                             Company Name (M.Cap)    DeciZen  \
# 0          NaN  Housing Development Finance Corporation Ltd (L)   1 Q V PT
# 1          NaN                            Bajaj Finance Ltd (L)   1 Q V PT
# 2          NaN                       Bharat Electronics Ltd (L)  1 Q V+ PT
# 3          NaN                                    Cipla Ltd (L)  1 Q V+ PT
# 4          NaN                              Dabur India Ltd (L)   1 Q V PT
# ..         ...                                              ...        ...
# 95         NaN                                   Zomato Ltd (L)   4 Q V PT
# 96         NaN                       Adani Transmission Ltd (L)  3 Q V+ PT
# 97         NaN                             Bandhan Bank Ltd (L)   1 Q V PT
# 98         NaN                       Adani Green Energy Ltd (L)   3 Q V PT
# 99         NaN                  FSN E-Commerce Ventures Ltd (L)   2 Q V PT
#
# ...
